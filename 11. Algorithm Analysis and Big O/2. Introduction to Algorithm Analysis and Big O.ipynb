# %%
def sum1(n):
    final_sum = 0
    
    for x in range(n+1):
        final_sum += x
        
    return final_sum

# %%
sum1(4)
# Out:
# 10

# %%
def sum2(n):
    return (n*(n+1))/2

# %%
sum2(4)
# Out:
# 10.0

# %%
# %timeit sum1(100)
# Out:
# 3.69 µs ± 54.6 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit sum2(100)
# Out:
# 124 ns ± 0.245 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
