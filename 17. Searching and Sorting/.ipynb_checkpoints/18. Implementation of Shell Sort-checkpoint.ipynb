# %%
def shell_sort(arr):
    
    #n/2,n/4,n/8.....
    n = len(arr)
    interval = n//2
    
    ##decrease till gap == 1, once gap == 1, its just a normal insertion sort
    while interval > 0:
        
        for i in range(interval,n):
            #perform insertion sort
            currentval = arr[i]
            position = i
            
            while position >= interval and arr[position-interval] > currentval:
                arr[position] = arr[position-interval]
                position -= interval
                
            arr[position] = currentval
        
        #decrease the gap
        interval = interval//2
        
    return arr

# %%
shell_sort([90,1,3,2,100,2029,100,90,1,3000])
# Out:
# [1, 1, 2, 3, 90, 90, 100, 100, 2029, 3000]

# %%
import random
arr = []
for a in range(1000):
    arr.append(random.randint(0,1000))

# %%
# %%time

shell_sort(arr)
# Out:
# CPU times: user 8.57 ms, sys: 116 µs, total: 8.69 ms
# Wall time: 8.63 ms
# [0,
#  1,
#  1,
#  3,
#  6,
#  8,
#  8,
#  8,
#  8,
#  9,
#  10,
#  10,
#  12,
#  12,
#  13,
#  16,
#  16,
#  20,
#  20,
#  20,
#  20,
#  21,
#  25,
#  25,
#  25,
#  26,
#  26,
#  26,
#  28,
#  29,
#  30,
#  31,
#  32,
#  33,
#  38,
#  40,
#  40,
#  42,
#  42,
#  44,
#  44,
#  45,
#  45,
#  47,
#  48,
#  48,
#  49,
#  49,
#  50,
#  50,
#  51,
#  53,
#  56,
#  57,
#  58,
#  59,
#  60,
#  61,
#  63,
#  63,
#  63,
#  64,
#  64,
#  66,
#  66,
#  69,
#  69,
#  70,
#  70,
#  71,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  73,
#  75,
#  77,
#  78,
#  79,
#  79,
#  83,
#  84,
#  84,
#  85,
#  85,
#  86,
#  86,
#  87,
#  88,
#  89,
#  93,
#  97,
#  98,
#  99,
#  101,
#  102,
#  105,
#  105,
#  105,
#  108,
#  108,
#  110,
#  111,
#  112,
#  113,
#  113,
#  117,
#  118,
#  120,
#  122,
#  123,
#  124,
#  124,
#  125,
#  127,
#  128,
#  128,
#  128,
#  129,
#  130,
#  130,
#  130,
#  131,
#  132,
#  132,
#  134,
# ...
