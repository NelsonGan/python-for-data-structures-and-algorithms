# %%
def insertion_sort(arr):
    
    l = len(arr)
    
    
    for i in range(1,l):
        
        currentvalue = arr[i]
        position = i
        
        #Keep going backward and check if swap needed
        while position > 0 and arr[position-1] > currentvalue:
            
            arr[position] = arr[position-1]
            position -= 1
            
        arr[position] = currentvalue
        
    return arr

# %%
# %%timeit

insertion_sort([90,1,3,2,100,2029,100,90,1,3000])
# Out:
# 3.41 µs ± 13.6 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
import random
arr = []
for a in range(1000):
    arr.append(random.randint(0,1000))

# %%
# %%time

insertion_sort(arr)
# Out:
# CPU times: user 85.3 ms, sys: 1.89 ms, total: 87.2 ms
# Wall time: 85.8 ms
# [3,
#  4,
#  4,
#  6,
#  6,
#  7,
#  8,
#  9,
#  9,
#  10,
#  10,
#  10,
#  10,
#  11,
#  14,
#  17,
#  18,
#  20,
#  21,
#  21,
#  22,
#  22,
#  22,
#  26,
#  26,
#  28,
#  29,
#  29,
#  32,
#  32,
#  36,
#  37,
#  37,
#  37,
#  38,
#  39,
#  41,
#  42,
#  43,
#  44,
#  45,
#  48,
#  48,
#  48,
#  50,
#  53,
#  54,
#  56,
#  57,
#  59,
#  60,
#  60,
#  60,
#  60,
#  60,
#  61,
#  61,
#  63,
#  64,
#  65,
#  66,
#  68,
#  69,
#  71,
#  71,
#  72,
#  72,
#  73,
#  74,
#  74,
#  74,
#  74,
#  75,
#  75,
#  75,
#  76,
#  77,
#  78,
#  78,
#  79,
#  80,
#  80,
#  81,
#  83,
#  84,
#  86,
#  86,
#  89,
#  93,
#  94,
#  94,
#  94,
#  96,
#  96,
#  96,
#  96,
#  96,
#  97,
#  98,
#  98,
#  98,
#  98,
#  99,
#  99,
#  100,
#  101,
#  102,
#  102,
#  102,
#  103,
#  107,
#  107,
#  108,
#  108,
#  109,
#  110,
#  111,
#  112,
#  114,
#  114,
#  114,
#  115,
#  116,
#  118,
#  119,
#  121,
#  121,
#  122,
#  124,
#  124,
#  125,
#  126,
#  128,
#  128,
#  128,
#  130,
#  132,
#  134,
#  134,
#  134,
#  134,
#  135,
#  137,
#  137,
#  138,
#  139,
#  141,
#  141,
#  143,
#  143,
#  144,
#  144,
#  144,
#  144,
#  144,
#  145,
#  147,
#  147,
#  148,
#  149,
#  149,
#  150,
#  150,
#  151,
#  152,
#  154,
#  155,
#  156,
#  156,
#  157,
#  157,
#  159,
#  159,
#  159,
#  159,
#  159,
#  161,
#  162,
#  163,
#  163,
#  164,
#  166,
#  166,
#  168,
#  175,
#  175,
#  176,
#  178,
#  178,
#  180,
#  181,
#  182,
#  185,
#  185,
#  186,
#  187,
#  188,
#  188,
#  188,
#  190,
#  191,
#  192,
#  193,
#  193,
#  195,
#  196,
#  196,
#  198,
#  199,
#  201,
#  201,
#  201,
#  201,
#  203,
#  204,
#  204,
#  207,
#  207,
#  209,
#  210,
#  210,
#  212,
#  214,
#  214,
#  214,
#  216,
#  217,
#  217,
#  219,
#  220,
#  221,
#  221,
#  222,
#  223,
#  223,
#  224,
#  224,
#  225,
#  225,
#  227,
#  228,
#  228,
#  229,
#  230,
#  230,
#  231,
#  232,
#  233,
#  234,
#  234,
#  235,
#  237,
#  237,
#  238,
#  238,
#  244,
#  244,
#  244,
#  245,
#  246,
#  247,
#  248,
#  252,
#  254,
#  255,
#  256,
#  257,
#  257,
#  261,
#  262,
#  263,
#  263,
#  264,
#  266,
#  268,
#  268,
#  270,
#  270,
#  272,
#  272,
#  273,
#  273,
#  273,
#  278,
#  278,
#  278,
#  279,
#  280,
#  282,
#  283,
#  284,
#  287,
#  287,
#  287,
#  291,
#  291,
#  294,
#  295,
#  297,
#  297,
#  298,
#  299,
#  299,
#  300,
#  302,
#  306,
#  313,
#  316,
#  317,
#  318,
#  321,
#  321,
#  323,
#  323,
#  324,
#  325,
#  326,
#  326,
#  326,
#  327,
#  329,
#  329,
#  330,
#  330,
#  330,
#  333,
#  333,
#  334,
#  336,
#  336,
#  336,
#  339,
#  343,
#  343,
#  343,
#  345,
#  345,
#  346,
#  348,
#  348,
#  352,
#  352,
#  354,
#  354,
#  354,
#  356,
#  357,
#  357,
#  357,
#  359,
#  359,
#  361,
#  361,
#  362,
#  362,
#  362,
#  365,
#  366,
#  369,
#  369,
#  369,
#  373,
#  374,
#  375,
#  376,
#  377,
#  377,
#  378,
#  379,
#  379,
#  380,
#  380,
#  381,
#  381,
#  381,
#  382,
#  382,
#  384,
#  385,
#  385,
#  385,
#  388,
#  388,
#  392,
#  393,
#  394,
#  394,
#  396,
#  396,
#  398,
#  399,
#  400,
#  401,
#  403,
#  404,
#  405,
#  407,
#  408,
#  409,
#  409,
#  411,
#  414,
#  415,
#  415,
#  415,
#  416,
#  416,
#  417,
#  417,
#  418,
#  419,
#  421,
#  422,
#  423,
#  424,
#  425,
#  425,
#  427,
#  429,
#  430,
#  430,
#  432,
#  434,
#  435,
#  436,
#  438,
#  438,
#  440,
#  440,
#  441,
#  444,
#  445,
#  448,
#  452,
#  452,
#  453,
#  454,
#  455,
#  455,
#  456,
#  456,
#  457,
#  457,
#  459,
#  461,
#  462,
#  462,
#  463,
#  466,
#  467,
#  472,
#  474,
#  474,
#  475,
#  476,
#  476,
#  479,
#  482,
#  482,
#  482,
#  483,
#  483,
#  484,
#  484,
#  486,
#  489,
#  491,
#  492,
#  492,
#  493,
#  494,
#  494,
#  494,
#  495,
#  499,
#  504,
#  505,
#  506,
#  507,
#  509,
#  509,
#  510,
#  510,
#  510,
#  512,
#  512,
#  512,
#  516,
#  516,
#  517,
#  518,
#  519,
#  520,
#  521,
#  522,
#  524,
#  525,
#  527,
#  529,
#  530,
#  531,
#  531,
#  534,
#  536,
#  536,
#  540,
#  540,
#  541,
#  542,
#  545,
#  545,
#  546,
#  548,
#  548,
#  548,
#  549,
#  550,
#  550,
#  552,
#  552,
#  554,
#  556,
#  558,
#  558,
#  559,
#  560,
#  561,
#  561,
#  566,
#  567,
#  568,
#  569,
#  570,
#  571,
#  571,
#  572,
#  573,
#  573,
#  573,
#  574,
#  575,
#  576,
#  577,
#  580,
#  581,
#  581,
#  584,
#  584,
#  585,
#  585,
#  585,
#  585,
#  586,
#  587,
#  587,
#  587,
#  587,
#  589,
#  590,
#  591,
#  592,
#  592,
#  593,
#  594,
#  594,
#  594,
#  595,
#  597,
#  598,
#  598,
#  601,
#  601,
#  606,
#  606,
#  607,
#  607,
#  607,
#  608,
#  610,
#  611,
#  613,
#  613,
#  617,
#  618,
#  620,
#  621,
#  621,
#  623,
#  623,
#  624,
#  624,
#  625,
#  626,
#  627,
#  627,
#  628,
#  629,
#  629,
#  630,
#  631,
#  632,
#  632,
#  634,
#  634,
#  634,
#  634,
#  635,
#  635,
#  637,
#  637,
#  637,
#  637,
#  637,
#  638,
#  639,
#  639,
#  639,
#  640,
#  643,
#  644,
#  644,
#  645,
#  645,
#  648,
#  650,
#  651,
#  652,
#  652,
#  654,
#  656,
#  657,
#  657,
#  659,
#  659,
#  659,
#  659,
#  661,
#  662,
#  663,
#  665,
#  665,
#  666,
#  666,
#  667,
#  671,
#  672,
#  673,
#  674,
#  674,
#  674,
#  675,
#  677,
#  678,
#  678,
#  678,
#  680,
#  680,
#  681,
#  682,
#  683,
#  686,
#  687,
#  688,
#  689,
#  689,
#  690,
#  694,
#  694,
#  695,
#  695,
#  696,
#  696,
#  697,
#  699,
#  699,
#  700,
#  702,
#  702,
#  704,
#  704,
#  708,
#  708,
#  708,
#  708,
#  709,
#  709,
#  709,
#  710,
#  710,
#  711,
#  714,
#  714,
#  715,
#  715,
#  716,
#  716,
#  716,
#  716,
#  717,
#  718,
#  719,
#  720,
#  720,
#  721,
#  721,
#  721,
#  723,
#  723,
#  724,
#  724,
#  725,
#  725,
#  726,
#  726,
#  727,
#  728,
#  729,
#  731,
#  732,
#  733,
#  733,
#  734,
#  735,
#  735,
#  737,
#  738,
#  739,
#  740,
#  740,
#  740,
#  741,
#  741,
#  741,
#  744,
#  744,
#  745,
#  745,
#  749,
#  751,
#  752,
#  754,
#  755,
#  756,
#  761,
#  761,
#  763,
#  763,
#  764,
#  766,
#  767,
#  768,
#  770,
#  770,
#  774,
#  775,
#  776,
#  781,
#  781,
#  782,
#  782,
#  782,
#  783,
#  784,
#  784,
#  785,
#  785,
#  785,
#  785,
#  787,
#  788,
#  789,
#  789,
#  790,
#  790,
#  791,
#  792,
#  792,
#  792,
#  793,
#  794,
#  796,
#  801,
#  801,
#  802,
#  802,
#  804,
#  807,
#  808,
#  808,
#  809,
#  811,
#  811,
#  812,
#  813,
#  816,
#  818,
#  818,
#  820,
#  820,
#  820,
#  821,
#  822,
#  822,
#  823,
#  823,
#  823,
#  826,
#  826,
#  826,
#  828,
#  829,
#  829,
#  830,
#  831,
#  832,
#  833,
#  833,
#  837,
#  838,
#  839,
#  840,
#  840,
#  841,
#  841,
#  843,
#  843,
#  844,
#  846,
#  847,
#  848,
#  849,
#  851,
#  853,
#  854,
#  855,
#  856,
#  857,
#  857,
#  858,
#  859,
#  860,
#  860,
#  861,
#  865,
#  865,
#  866,
#  866,
#  867,
#  867,
#  868,
#  868,
#  869,
#  869,
#  870,
#  870,
#  871,
#  871,
#  874,
#  875,
#  876,
#  877,
#  878,
#  880,
#  880,
#  881,
#  881,
#  882,
#  882,
#  883,
#  884,
#  885,
#  885,
#  886,
#  888,
#  888,
#  889,
#  889,
#  890,
#  891,
#  893,
#  893,
#  894,
#  894,
#  896,
#  896,
#  896,
#  898,
#  901,
#  901,
#  902,
#  902,
#  903,
#  905,
#  905,
#  907,
#  907,
#  908,
#  909,
#  909,
#  910,
#  911,
#  912,
#  912,
#  913,
#  915,
#  915,
#  915,
#  917,
#  918,
#  920,
#  920,
#  922,
#  923,
#  924,
#  924,
#  925,
#  926,
#  927,
#  927,
#  927,
#  927,
#  928,
#  929,
#  930,
#  930,
#  931,
#  931,
#  932,
#  933,
#  933,
#  933,
#  933,
#  934,
#  935,
#  935,
#  936,
#  936,
#  936,
#  936,
#  937,
#  938,
#  939,
#  940,
#  941,
#  941,
#  942,
#  943,
#  943,
#  944,
#  944,
#  945,
#  946,
#  947,
#  947,
#  949,
#  950,
#  951,
#  951,
#  952,
#  952,
#  952,
#  954,
#  954,
#  955,
#  957,
#  958,
#  959,
#  960,
#  960,
#  961,
#  962,
#  963,
#  963,
#  964,
#  965,
#  966,
#  966,
#  966,
#  967,
#  970,
#  970,
#  970,
#  972,
#  973,
#  973,
#  976,
#  977,
#  978,
#  979,
#  980,
#  982,
#  982,
#  983,
#  986,
#  988,
#  993,
#  994,
#  995,
#  995,
#  998]
